# %%
from config import genius_token
import lyricsgenius
import pandas as pd

# %%
df = pd.read_csv("tracks.csv")
df[targets].head()
targets = ["Artist", "Title"]
genius = lyricsgenius.Genius(genius_token)
lyrics_dict = {}

lyrics_dict_sklearn = {}
for record in df[targets].itertuples():
    song = genius.search_song(record[2], record[1])
    lyrics_dict[record[2]] = song.lyrics.strip().replace("\n", " ").split(' ')
    lyrics_dict_sklearn[record[2]] = song.lyrics.strip()
# Out:
# Searching for "Ms Jackson" by Outkast...
# Done.
# Searching for "Savage" by Whethan...
# Done.
# Searching for "It’s Tricky" by Run DMC...
# Done.
# Searching for "Another Life" by KREAM...
# Done.
# Searching for "Classic" by The Knocks...
# Done.
# Searching for "Did You Wrong" by Sweater Beats...
# Done.
# Searching for "Taped Up Heart" by KREAM...
# Done.
# Searching for "Aftershock" by Cash Cash...
# Done.
# Searching for "Basically Over You" by Alex Newell...
# Done.
# Searching for "Rich Boy" by Galantis...
# Done.
# Searching for "LA" by Dawn Richard...
# Done.
# Searching for "Cheerleader (Felix Jaehn remix)" by OMI...
# Done.
# Searching for "Bonbon" by Era Istrefi...
# Done.
# Searching for "Broccoli" by D.R.A.M....
# Done.
# Searching for "Physical" by St. Lucia...
# Done.
# Searching for "Grown Up" by No Wyld...
# Done.
# Searching for "Let Me Know" by No Wyld...
# Done.
# Searching for "No Pressure" by Little Boots...
# Done.
# Searching for "False Alarm" by Matoma...
# Done.
# Searching for "Rockabye" by Clean Bandit...
# Done.
# Searching for "Sound Of Your Heart" by Shawn Hook...
# Done.
# Searching for "Brightside" by Icona Pop...
# Done.
# Searching for "The Night" by New Reign...
# Done.
# Searching for "What You Waiting For" by New Reign...
# Done.
# Searching for "Run It" by JD Reid...
# Done.
# Searching for "I Love It" by Icona Pop...
# Done.
# Searching for "Your Love" by Rising Seas...
# Done.
# Searching for "Dracula" by Bea Miller...
# Done.
# Searching for "Fire N Gold" by Bea Miller...
# Done.
# Searching for "History" by Olivia Holt...
# Done.
# Searching for "Home" by Morgxn...
# Done.
# Searching for "Girls On Boys" by Galantis...
# Done.
# Searching for "Hunter" by Galantis...
# Done.
# Searching for "Tell Me You Love Me" by Galantis...
# Done.
# Searching for "Love On Me" by Galantis...
# Done.
# Searching for "No Money" by Galantis...
# Done.
# Searching for "Make It High" by Ost & Meyer vs. Stage Rockers...
# No results found for: 'Make It High Ost & Meyer vs. Stage Rockers'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-105-1b8328e7fa20> in <module>
#       8 for record in df[targets].itertuples():
#       9     song = genius.search_song(record[2], record[1])
# ---> 10     lyrics_dict[record[2]] = song.lyrics.strip().replace("\n", " ").split(' ')
#      11     lyrics_dict_sklearn[record[2]] = song.lyrics.strip()
#      12
#
# AttributeError: 'NoneType' object has no attribute 'lyrics'

# %%
len(lyrics_dict)
# Out:
# 36

# %%
from collections import Counter
z = Counter(lyrics_dict['Ms Jackson']).most_common()

# %%
z = Counter(track)

buffer = 0
for x in z.elements():
    buffer += 1
    
print(162./buffer * 100)

song = genius.search_song("Versace", "Migos")
track = song.lyrics.strip().replace("\n", " ").replace(",", "").split(' ')
count_df = pd.DataFrame(Counter(track).most_common(), columns=["word", "count"])
count_df["percentage"] = round(count_df["count"] / buffer, 3) * 100
# Out:
# 30.916030534351147

# %%
vocab = []
for val in lyrics_dict.values():
    vocab.extend(val)
    
def make_one_hot(song_word_list, vocab_vector):
    counts = Counter(song_word_list)
    
    one_hot =  {}
    for word in song_word_list:
        one_hot[word] = counts[word]
        
    for word in vocab_vector:
        if word not in song_word_list:
            one_hot[word] = 0
        
    return one_hot

for k, v in lyrics_dict.items()
make_one_hot(lyrics_dict["Ms Jackson"], vocab)
# Out:
# {'[Intro:': 1,
#  'André': 4,
#  '3000]': 4,
#  'Yeah,': 2,
#  'this': 5,
#  'one': 3,
#  'right': 1,
#  'here': 1,
#  'goes': 1,
#  'out': 5,
#  'To': 1,
#  'all': 3,
#  'the': 26,
#  "baby's": 1,
#  "mamas'": 2,
#  'mamas': 2,
#  'Mamas,': 1,
#  'mamas,': 1,
#  'baby': 3,
#  'go': 2,
#  'like': 4,
#  '': 8,
#  '[Hook:': 1,
#  "I'm": 12,
#  'sorry,': 10,
#  'Ms.': 12,
#  'Jackson,': 11,
#  'ooh,': 10,
#  'I': 32,
#  'am': 10,
#  'for': 12,
#  'real': 10,
#  'Never': 10,
#  'meant': 10,
#  'to': 18,
#  'make': 10,
#  'your': 16,
#  'daughter': 11,
#  'cry': 10,
#  'apologize': 10,
#  'a': 20,
#  'trillion': 10,
#  'times': 11,
#  '[Verse': 3,
#  '1:': 1,
#  'Big': 2,
#  'Boi]': 2,
#  'My': 2,
#  'drama': 1,
#  'mama': 2,
#  "don't": 1,
#  'me': 4,
#  'She': 4,
#  'be': 6,
#  "doin'": 1,
#  'things': 1,
#  "havin'": 1,
#  'them': 1,
#  'boys': 1,
#  'come': 1,
#  'from': 1,
#  'her': 7,
#  'neighborhood': 1,
#  'studio,': 1,
#  'tryna': 1,
#  'fight': 1,
#  'need': 2,
#  'get': 2,
#  'piece': 1,
#  'of': 7,
#  'American': 1,
#  'pie': 1,
#  'and': 12,
#  'take': 1,
#  'bite': 1,
#  "That's": 1,
#  'my': 6,
#  'house,': 1,
#  "I'll": 2,
#  'disconnect': 1,
#  'cable': 1,
#  'turn': 1,
#  'lights': 1,
#  'And': 5,
#  'let': 1,
#  'know': 3,
#  'grandchild': 1,
#  'is': 2,
#  'not': 1,
#  'pay': 2,
#  'check': 1,
#  'Private': 1,
#  'school,': 1,
#  'daycare,': 1,
#  'shit,': 1,
#  'medical': 1,
#  'bills—I': 1,
#  'that': 8,
#  'love': 2,
#  'mom': 1,
#  'everything': 1,
#  'But': 2,
#  'see,': 2,
#  "ain't": 3,
#  'only': 1,
#  'who': 2,
#  'laid': 1,
#  'down': 2,
#  'wanna': 1,
#  'rib': 1,
#  'you': 9,
#  'up': 2,
#  'start': 1,
#  'custody': 1,
#  'war': 1,
#  'lawyers': 1,
#  'stay': 1,
#  'Shit,': 2,
#  'never': 2,
#  'got': 3,
#  'chance': 1,
#  'hear': 1,
#  'side': 1,
#  'story': 1,
#  'We': 1,
#  'was': 1,
#  'divided': 1,
#  'had': 2,
#  'fish': 1,
#  'fries': 1,
#  'cookouts': 1,
#  "child's": 1,
#  'birthday': 1,
#  'invited,': 1,
#  'despite': 1,
#  'it': 2,
#  'show': 1,
#  'utmost': 1,
#  'respect': 1,
#  'when': 2,
#  'fall': 1,
#  'through': 1,
#  'All': 1,
#  'do': 1,
#  'defend': 1,
#  'lady': 1,
#  'call': 1,
#  'you,': 1,
#  'yeah': 1,
#  '[Hook]': 3,
#  '[Bridge:': 1,
#  'Me': 1,
#  'special': 1,
#  'thing': 4,
#  "goin'": 1,
#  'on': 7,
#  'You': 5,
#  'say': 2,
#  "it's": 2,
#  'puppy': 2,
#  'love,': 1,
#  'we': 3,
#  'full-grown': 1,
#  'Hope': 1,
#  'feel': 3,
#  'this,': 2,
#  'way': 3,
#  'forever': 3,
#  'can': 2,
#  'plan': 1,
#  'pretty': 1,
#  'picnic': 1,
#  "can't": 3,
#  'predict': 1,
#  'weather,': 1,
#  'Jackson': 1,
#  '2:': 1,
#  'Ten': 1,
#  'nine,': 1,
#  'now': 1,
#  'if': 1,
#  "lyin',": 1,
#  'find': 1,
#  'The': 1,
#  'quickest': 1,
#  'muzzle,': 1,
#  'throw': 1,
#  'mouth': 2,
#  'decline': 1,
#  'King': 1,
#  'meets': 1,
#  'queen,': 1,
#  'then': 1,
#  'Together': 1,
#  'dream': 1,
#  "'bout": 1,
#  'crib': 1,
#  'with': 1,
#  'Goodyear': 1,
#  'swing': 1,
#  'On': 1,
#  'oak': 1,
#  'tree,': 1,
#  'hope': 1,
#  'Forever,': 1,
#  'ever?': 2,
#  'Forever': 2,
#  'seems': 1,
#  'long': 1,
#  'until': 1,
#  "you're": 1,
#  'grown': 1,
#  'notice': 1,
#  'day-by-day': 1,
#  'ruler': 1,
#  'too': 1,
#  'wrong': 1,
#  'intentions': 1,
#  'were': 1,
#  'good,': 1,
#  'wish': 1,
#  'could': 1,
#  'Become': 1,
#  'magician': 1,
#  'abracadabra': 1,
#  'sadder': 1,
#  'Thoughts': 1,
#  'me,': 1,
#  'thoughts': 2,
#  'she,': 1,
#  'he': 2,
#  "Askin'": 1,
#  'what': 2,
#  'happened': 2,
#  "feelin'": 1,
#  'pray': 1,
#  'so': 1,
#  'much': 1,
#  'about': 1,
#  'it,': 1,
#  'some': 1,
#  'knee': 1,
#  'pads': 1,
#  'It': 1,
#  'reason,': 1,
#  'mad': 1,
#  'So': 2,
#  "everything's": 1,
#  'cool': 1,
#  'yes,': 1,
#  'will': 1,
#  'present': 1,
#  'first': 1,
#  'day': 1,
#  'school': 1,
#  'graduation': 1,
#  '3:': 1,
#  '"Look': 1,
#  'at': 2,
#  'treats': 1,
#  'me"': 1,
#  'look': 1,
#  'treat': 1,
#  'little': 1,
#  'nosy-ass': 1,
#  'homegirls': 1,
#  'Done': 1,
#  'ass': 1,
#  'sent': 1,
#  'creek,': 1,
#  'G': 2,
#  'Without': 1,
#  'paddle,': 1,
#  'left': 1,
#  'straddle': 1,
#  'ride': 1,
#  'knew': 1,
#  'girl': 1,
#  "speakin'": 1,
#  'no': 1,
#  'more': 1,
#  '‘Cause': 1,
#  'dick': 1,
#  'in': 1,
#  'Know': 1,
#  "talkin'": 1,
#  'about?': 1,
#  'Jealousy,': 1,
#  'infidelity,': 1,
#  'envy,': 1,
#  'cheating,': 1,
#  'beating': 1,
#  'In': 1,
#  'end': 1,
#  'they': 1,
#  'same': 2,
#  "placin'": 1,
#  'blame': 1,
#  'on?': 1,
#  'keep': 1,
#  "singin'": 1,
#  'song': 1,
#  'Let': 1,
#  'bygones': 1,
#  'bygones,': 1,
#  'hell': 1,
#  'MAX]': 0,
#  'loving': 0,
#  'morning': 0,
#  'Got': 0,
#  'singing': 0,
#  'pouring': 0,
#  'rain': 0,
#  'wrapped': 0,
#  'around': 0,
#  'finger': 0,
#  'perfect': 0,
#  'palm': 0,
#  'hand': 0,
#  'Message': 0,
#  "couldn't": 0,
#  'clearer': 0,
#  'Like': 0,
#  'metaphor': 0,
#  'make-believe': 0,
#  'somebody': 0,
#  "wouldn't": 0,
#  'pinch': 0,
#  'That': 0,
#  'would': 0,
#  '[Pre-Break:': 0,
#  'Well': 0,
#  'pardon': 0,
#  'manners': 0,
#  'Just': 0,
#  'something': 0,
#  'turns': 0,
#  'savage': 0,
#  'If': 0,
#  "I'ma": 0,
#  'honest': 0,
#  'help': 0,
#  'but': 0,
#  'losing': 0,
#  'balance': 0,
#  'running': 0,
#  'circles': 0,
#  'please': 0,
#  '[Break:': 0,
#  'Savage': 0,
#  'every': 0,
#  'time': 0,
#  'walk': 0,
#  'by': 0,
#  'magic': 0,
#  'air': 0,
#  'Promise': 0,
#  'drive': 0,
#  'sweep': 0,
#  '[Intro]': 0,
#  'This': 0,
#  'speech': 0,
#  'recital,': 0,
#  'think': 0,
#  'very': 0,
#  'vital': 0,
#  'rock': 0,
#  '(a': 0,
#  'rhyme),': 0,
#  "that's": 0,
#  '(on': 0,
#  'time)': 0,
#  '"It\'s': 0,
#  'Tricky"': 0,
#  'title,': 0,
#  'go...': 0,
#  '[Chorus]': 0,
#  "It's": 0,
#  'Tricky': 0,
#  'rhyme,': 0,
#  'rhyme': 0,
#  'Tricky...': 0,
#  '(Tricky)': 0,
#  'Tr-tr-tr-tricky': 0,
#  'Trrrrrrrrrrricky': 0,
#  '1]': 0,
#  'met': 0,
#  'girlie,': 0,
#  'hair': 0,
#  'kinda': 0,
#  'curly': 0,
#  'Went': 0,
#  'house': 0,
#  'bust': 0,
#  'out,': 0,
#  'leave': 0,
#  'early': 0,
#  'These': 0,
#  'girls': 0,
#  'are': 0,
#  'really': 0,
#  'sleazy,': 0,
#  'just': 0,
#  'Or': 0,
#  'spend': 0,
#  'said': 0,
#  'easy"': 0,
#  '(How': 0,
#  'D?)': 0,
#  '(Trrrrrricky)': 0,
#  '2]': 0,
#  'New': 0,
#  'York,': 0,
#  'people': 0,
#  'talk': 0,
#  'try': 0,
#  'us': 0,
#  'They': 0,
#  '(hawk)': 0,
#  '(walk)': 0,
#  'because': 0,
#  'have': 0,
#  'city,': 0,
#  'pity': 0,
#  "'cause": 0,
#  'hide': 0,
#  'Tinted': 0,
#  'windows': 0,
#  'mean': 0,
#  "nothin',": 0,
#  "who's": 0,
#  'inside': 0,
#  'huh!': 0,
#  '3]': 0,
#  'When': 0,
#  'wake': 0,
#  'mostly': 0,
#  "singin',": 0,
#  'phone': 0,
#  "ringin'": 0,
#  'cause': 0,
#  "braggin',": 0,
#  "naggin'": 0,
#  'star': 0,
#  'Always': 0,
#  "tearin'": 0,
#  "wearin',": 0,
#  "they're": 0,
#  'far': 0,
#  'A': 0,
#  'named': 0,
#  'Carol': 0,
#  'follows': 0,
#  'Darryl': 0,
#  'gig': 0,
#  'play': 0,
#  'Then': 0,
#  'D': 0,
#  'dissed': 0,
#  'dismissed': 0,
#  'her,': 0,
#  "she's": 0,
#  "jockin'": 0,
#  'Jay': 0,
#  "cryin'": 0,
#  'TV': 0,
#  'even': 0,
#  'bother': 0,
#  'poor': 0,
#  'father': 0,
#  "he's": 0,
#  'it?)': 0,
#  'Tr-tr-tr-tr-tr-tricky': 0,
#  '(Tr-Tr-Tr-Tricky)': 0,
#  'Tr-tr-tr...': 0,
#  '[Outro]': 0,
#  'thugs': 0,
#  '(we': 0,
#  'use': 0,
#  'drugs)': 0,
#  'assume': 0,
#  'own)': 0,
#  'offer': 0,
#  'coke': 0,
#  '(and': 0,
#  'lots': 0,
#  'dope)': 0,
#  'alone': 0,
#  "y'all": 0,
#  "(y'all),": 0,
#  'quit': 0,
#  '(rock!)': 0,
#  'shock': 0,
#  'it...': 0,
#  'Mark': 0,
#  'Asari]': 0,
#  'Maybe': 0,
#  'sky': 0,
#  'open': 0,
#  'streets': 0,
#  'golden,': 0,
#  'babe': 0,
#  'our': 0,
#  'float': 0,
#  'oceans': 0,
#  'storms': 0,
#  'hate': 0,
#  'far,': 0,
#  'baby,': 0,
#  'away': 0,
#  "there's": 0,
#  'longer': 0,
#  'called': 0,
#  '"us"': 0,
#  'needed': 0,
#  'change': 0,
#  '[Chorus:': 0,
#  'another': 0,
#  'life': 0,
#  'together,': 0,
#  "goodbye's": 0,
#  'life,': 0,
#  'aisle': 0,
#  'picture': 0,
#  'world': 0,
#  'used': 0,
#  'to,': 0,
#  'better': 0,
#  'shame': 0,
#  'separate': 0,
#  'ways': 0,
#  'speed': 0,
#  'lifetime': 0,
#  'Baby,': 0,
#  'yours,': 0,
#  'maybe': 0,
#  'tonight': 0,
#  '1,': 0,
#  '2,': 0,
#  '3,': 0,
#  '4': 0,
#  'Come': 0,
#  'shy': 0,
#  "Don't": 0,
#  'shy,': 0,
#  'summer': 0,
#  'time,': 0,
#  'high': 0,
#  'Oh': 0,
#  'masterpiece': 0,
#  'eyes': 0,
#  'mine': 0,
#  'Sweet': 0,
#  'apple': 0,
#  'pie,': 0,
#  'caught': 0,
#  'energy': 0,
#  'future': 0,
#  'came': 0,
#  'see': 0,
#  '[Pre-Hook]': 0,
#  'feels': 0,
#  'classic': 0,
#  'Cause': 0,
#  'feels,': 0,
#  'yeah,': 0,
#  'lost': 0,
#  'minds': 0,
#  'Between': 0,
#  'birds': 0,
#  'bees': 0,
#  'Buzzing': 0,
#  'under': 0,
#  'blue': 0,
#  'till': 0,
#  'full': 0,
#  'moon': 0,
#  'rise': 0,
#  'Playing': 0,
#  'chemistry': 0,
#  'Baby': 0,
#  'me,?': 0,
#  'classic,': 0,
#  'mmm': 0,
#  '[Bridge]': 0,
#  "We're": 0,
#  'looking': 0,
#  'fun': 0,
#  "what's": 0,
#  'gonna': 0,
#  'come,': 0}

# %%
# Out:
# '[Intro:'
