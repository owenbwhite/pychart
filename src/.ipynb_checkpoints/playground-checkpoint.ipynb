# %%
from client import Chartmetric
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import json
import os
from config import chartmetric_token
from config import refresh_command

# %%
def refresh_token():
    os.system(refresh_command)


cm = Chartmetric(chartmetric_token)
df = pd.read_csv('tracks.csv')
tests = df.loc[df.ISRC.notnull()]

# %%
isrc_dict = {}
for test in tests.ISRC.head(50):
    search_results = cm.search(test)
    try:
        cm_id = search_results['obj']['tracks'][0]['id']
        name_of_song = search_results["obj"]["tracks"][0]["name"]
        isrc_dict[name_of_song] = dict(cm_id=cm_id, isrc=test)
    except TypeError:
        print(f'{test} not found')

# %%
song_data_dict = {}
for k, v in isrc_dict.items():
    song_data_dict[k] = cm.track(str(v['cm_id']))

# %%
song_data_dict
# Out:
# {'Ms. Jackson': {'obj': {'id': 15048628,
#    'name': 'Ms. Jackson',
#    'isrc': 'USAR10100783',
#    'image_url': 'https://i.scdn.co/image/95498205e9169ea726cc7b27d7bffa66e05e41fa',
#    'duration_ms': 239360,
#    'composer_name': 'André Benjamin, Antwan Patton & David Sheats',
#    'artists': [{'id': 180,
#      'name': 'OutKast',
#      'mbid': '73fdb566-a9b1-494c-9f32-51768ec9fd27',
#      'image_url': None,
#      'cover_url': None,
#      'code2': 'US',
#      'gender': 1,
#      'isni': None,
#      'description': None,
#      'created_at': '2016-11-26',
#      'hometown_city': None,
#      'current_city': None,
#      'date_of_birth': '1991-01-01',
#      'date_of_death': None}],
#    'albums': [{'id': 306001,
#      'name': 'Big Boi & Dre Present, Outkast',
#      'upc': '888880763624',
#      'release_date': '2001-10-04T00:00:00.000Z',
#      'label': 'Arista/LaFace Records',
#      'image_url': 'https://i.scdn.co/image/95498205e9169ea726cc7b27d7bffa66e05e41fa',
#      'popularity': 0},
#     {'id': 1189534,
#      'name': 'Big Boi & Dre Present, Outkast',
#      'upc': '730082609326',
#      'release_date': '2001-10-04T00:00:00.000Z',
#      'label': 'Arista/LaFace Records',
#      'image_url': 'https://i.scdn.co/image/95498205e9169ea726cc7b27d7bffa66e05e41fa',
#      'popularity': 47},
#     {'id': 1586038,
#      'name': 'Big Boi & Dre Present...Outkast',
#      'upc': '886972859828',
#      'release_date': '2001-10-04T00:00:00.000Z',
#      'label': 'Sony BMG Music Entertainment',
#      'image_url': 'https://i.scdn.co/image/d9cbbfc741bcc6f00cfc8d4e75128d2e74aced55',
#      'popularity': 0}],
#    'tags': 'Hip-Hop/Rap,Music,Dirty South,Alternative Rap,Rock',
#    'cm_audio_features': {'key': 4,
#     'mode': 0,
#     'danceability': 0.838,
#     'energy': 0.837,
#     'speechiness': 0.275,
#     'acousticness': 0.199,
#     'instrumentalness': 0,
#     'liveness': 0.0914,
#     'valence': 0.693,
#     'tempo': 95.029,
#     'loudness': -3.9},
#    'release_date': '2001-10-04T00:00:00.000Z',
#    'lastfm': {'name': 'Ms. Jackson',
#     'mbid': '65493c37-6583-4f7d-bb9c-56d07487da1a',
#     'url': 'https://www.last.fm/music/OutKast/_/Ms.+Jackson',
#     'duration': '211000',
#     'streamable': {'#text': '0', 'fulltrack': '0'},
#     'listeners': '886884',
#     'playcount': '4158381',
#     'artist': {'name': 'OutKast',
#      'mbid': '73fdb566-a9b1-494c-9f32-51768ec9fd27',
#      'url': 'https://www.last.fm/music/OutKast'},
#     'album': {'artist': 'OutKast',
#      'title': 'Stankonia',
#      'mbid': '71f0eea5-99fc-38e6-b0b2-390dcd50bf24',
#      'url': 'https://www.last.fm/music/OutKast/Stankonia',
#      'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/363933ce720b4406ad8ca8b25f0406c9.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/363933ce720b4406ad8ca8b25f0406c9.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/363933ce720b4406ad8ca8b25f0406c9.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/363933ce720b4406ad8ca8b25f0406c9.png',
#        'size': 'extralarge'}],
#      '@attr': {'position': '5'}},
#     'toptags': {'tag': [{'name': 'Hip-Hop',
#        'url': 'https://www.last.fm/tag/Hip-Hop'},
#       {'name': 'rap', 'url': 'https://www.last.fm/tag/rap'},
#       {'name': 'hip hop', 'url': 'https://www.last.fm/tag/hip+hop'},
#       {'name': 'outkast', 'url': 'https://www.last.fm/tag/outkast'},
#       {'name': 'pop', 'url': 'https://www.last.fm/tag/pop'}]},
#     'wiki': {'published': '13 Oct 2010, 18:17',
#      'summary': '"Ms. Jackson" is a song by OutKast and the second single from their fourth album Stankonia. It topped the U.S. charts for the week of February 17, 2001, and won a 2002 Grammy Award for Best Rap Performance by a Duo or Group. It also reached number one in Germany and number two in the United Kingdom, held from the top spot by Atomic Kitten\'s "Whole Again".\nThe titular "Ms. Jackson" is the real-life mother of Erykah Badu, André 3000\'s ex-girlfriend and the mother of his son Seven. <a href="http://www.last.fm/music/OutKast/_/Ms.+Jackson">Read more on Last.fm</a>.',
#      'content': '"Ms. Jackson" is a song by OutKast and the second single from their fourth album Stankonia. It topped the U.S. charts for the week of February 17, 2001, and won a 2002 Grammy Award for Best Rap Performance by a Duo or Group. It also reached number one in Germany and number two in the United Kingdom, held from the top spot by Atomic Kitten\'s "Whole Again".\nThe titular "Ms. Jackson" is the real-life mother of Erykah Badu, André 3000\'s ex-girlfriend and the mother of his son Seven. The song discusses the problems that break-ups, separation, and divorce can have on a couple, and the animosity that a woman\'s mother can have for her daughter\'s former boyfriend or husband.\nThe single helped sell the album following mixed reaction to the lead single "B.O.B.", which, despite nearly universal acclaim from critics, failed to chart on the U.S. Billboard Hot 100 and only reached #69 on the Billboard Hot R&B/Hip-Hop Songs chart.\nThe song samples "Strawberry Letter 23" by The Brothers Johnson (with pitch shifting and reversing) and features an altered version of a tune from "Bridal Chorus" from the opera Lohengrin by German composer Richard Wagner (also known as the "wedding march"), played on piano. <a href="http://www.last.fm/music/OutKast/_/Ms.+Jackson">Read more on Last.fm</a>. User-contributed text is available under the Creative Commons By-SA License; additional terms may apply.'}},
#    'cm_statistics': {'num_sp_playlists': 328,
#     'num_sp_editorial_playlists': 1,
#     'num_am_playlists': 0,
#     'num_am_editorial_playlists': 0,
#     'num_de_playlists': 21,
#     'num_de_editorial_playlists': 9,
#     'num_az_playlists': 0,
#     'num_az_editorial_playlists': 0,
#     'num_yt_playlists': 0,
#     'num_yt_editorial_playlists': 0,
#     'yt_playlist_total_reach': None,
#     'sp_popularity': 46,
#     'sp_playlist_total_reach': '343932',
#     'de_playlist_total_reach': '72517'}}},
#  'Savage (feat. Flux Pavillion & MAX)': {'obj': {'id': 15092670,
#    'name': 'Savage (feat. Flux Pavillion & MAX)',
#    'isrc': 'USAT21603407',
#    'image_url': 'https://i.scdn.co/image/5dc15b41ac1bb8b19302149df776f3327a466a1c',
#    'duration_ms': 205333,
#    'composer_name': None,
#    'artists': [{'id': 64548,
#      'name': 'Whethan',
#      'mbid': None,
#      'image_url': None,
#      'cover_url': None,
#      'code2': 'US',
#      'gender': 1,
#      'isni': None,
#      'description': None,
#      'created_at': '2016-11-26',
#      'hometown_city': 7057,
#      'current_city': None,
#      'date_of_birth': None,
#      'date_of_death': None}],
#    'albums': [{'id': 3962677,
#      'name': 'Savage (feat. Flux Pavillion & MAX)',
#      'upc': '075679902061',
#      'release_date': '2016-12-06T00:00:00.000Z',
#      'label': 'Big Beat Records',
#      'image_url': 'https://i.scdn.co/image/5dc15b41ac1bb8b19302149df776f3327a466a1c',
#      'popularity': 48}],
#    'tags': None,
#    'cm_audio_features': {'key': 7,
#     'mode': 1,
#     'danceability': 0.679,
#     'energy': 0.662,
#     'speechiness': 0.0773,
#     'acousticness': 0.151,
#     'instrumentalness': 0,
#     'liveness': 0.376,
#     'valence': 0.357,
#     'tempo': 90.054,
#     'loudness': -5.861},
#    'release_date': '2016-12-06T00:00:00.000Z',
#    'lastfm': {'name': 'Savage (Feat. Flux Pavillion & MAX)',
#     'url': 'https://www.last.fm/music/Whethan/_/Savage+(Feat.+Flux+Pavillion+&+MAX)',
#     'duration': '0',
#     'streamable': {'#text': '0', 'fulltrack': '0'},
#     'listeners': '375',
#     'playcount': '2061',
#     'artist': {'name': 'Whethan', 'url': 'https://www.last.fm/music/Whethan'},
#     'toptags': {'tag': []}},
#    'cm_statistics': {'num_sp_playlists': 81,
#     'num_sp_editorial_playlists': 1,
#     'num_am_playlists': 0,
#     'num_am_editorial_playlists': 0,
#     'num_de_playlists': 3,
#     'num_de_editorial_playlists': 0,
#     'num_az_playlists': 0,
#     'num_az_editorial_playlists': 0,
#     'num_yt_playlists': 0,
#     'num_yt_editorial_playlists': 0,
#     'yt_playlist_total_reach': None,
#     'sp_popularity': 53,
#     'sp_playlist_total_reach': '231',
#     'de_playlist_total_reach': '3722'}}},
#  "It's Tricky": {'obj': {'id': 15051716,
#    'name': "It's Tricky",
#    'isrc': 'USAR18600005',
#    'image_url': 'https://i.scdn.co/image/00a8c686d47eaef4c5a30c5ae84c62c512c52637',
#    'duration_ms': 184720,
#    'composer_name': 'Run-DMC, Joseph Ward Simmons & Jason Mizell',
#    'artists': [{'id': 206566,
#      'name': 'Run–D.M.C.',
#      'mbid': '5ecc3f72-20a6-47a0-8dc5-fb0b3dadeea0',
#      'image_url': None,
#      'cover_url': None,
#      'code2': 'US',
#      'gender': 1,
#      'isni': None,
#      'description': None,
#      'created_at': '2016-11-26',
#      'hometown_city': None,
#      'current_city': None,
#      'date_of_birth': '1982-01-01',
#      'date_of_death': '2002-10-30'},
#     {'id': 427901,
#      'name': 'Jason Mizell',
#      'mbid': None,
#      'image_url': None,
#      'cover_url': None,
#      'code2': None,
#      'gender': None,
#      'isni': None,
#      'description': None,
#      'created_at': '2017-02-14',
#      'hometown_city': None,
#      'current_city': None,
#      'date_of_birth': None,
#      'date_of_death': None},
#     {'id': 480631,
#      'name': 'Joseph Ward Simmons',
#      'mbid': None,
#      'image_url': None,
#      'cover_url': None,
#      'code2': None,
#      'gender': None,
#      'isni': None,
#      'description': None,
#      'created_at': '2017-02-20',
#      'hometown_city': None,
#      'current_city': None,
#      'date_of_birth': None,
#      'date_of_death': None},
#     {'id': 480632,
#      'name': 'Darryl McDaniels',
#      'mbid': None,
#      'image_url': None,
#      'cover_url': None,
#      'code2': None,
#      'gender': None,
#      'isni': None,
#      'description': None,
#      'created_at': '2017-02-20',
#      'hometown_city': None,
#      'current_city': None,
#      'date_of_birth': None,
#      'date_of_death': None}],
#    'albums': [{'id': 4639,
#      'name': 'The Best Year Of My Life: 1987',
#      'upc': '884977504750',
#      'release_date': '2010-04-30T00:00:00.000Z',
#      'label': 'Sony Music Entertainment',
#      'image_url': 'https://i.scdn.co/image/bb48be044225e3677fd3e27575923c83a3c45635',
#      'popularity': 23},
#     {'id': 15547,
#      'name': 'The Greatest Hits',
#      'upc': '743219806024',
#      'release_date': '2002-09-10T00:00:00.000Z',
#      'label': 'Arista',
#      'image_url': 'https://i.scdn.co/image/a19a5fafa761d5571f3b9534283502b52cecef6c',
#      'popularity': 51},
#     {'id': 59291,
#      'name': 'The Essential Run-DMC',
#      'upc': '886443669055',
#      'release_date': '2012-10-30T00:00:00.000Z',
#      'label': 'Arista/Legacy',
#      'image_url': 'https://i.scdn.co/image/0a89a45a481c70939ff5a285e7e3e81fd1a6350f',
#      'popularity': 33},
#     {'id': 134170,
#      'name': 'Collections',
#      'upc': '828768957127',
#      'release_date': '1999-12-31T00:00:00.000Z',
#      'label': 'Sony BMG Music Entertainment',
#      'image_url': 'https://i.scdn.co/image/cdc6e6ad0ff3f40271aff2ec0edb229e2cdf5063',
#      'popularity': 17},
#     {'id': 155246,
#      'name': "It's Like This - The Best Of",
#      'upc': '888880968432',
#      'release_date': '2009-03-26T00:00:00.000Z',
#      'label': 'Sony Music Entertainment',
#      'image_url': 'https://i.scdn.co/image/8afe25f7c369004cb95dbb935c546a33406e0bf2',
#      'popularity': 28},
#     {'id': 276431,
#      'name': "100 Hits of the 80's - Volume 2",
#      'upc': '884977950618',
#      'release_date': '2011-04-08T00:00:00.000Z',
#      'label': 'Sony Music Entertainment',
#      'image_url': 'https://i.scdn.co/image/00a8c686d47eaef4c5a30c5ae84c62c512c52637',
#      'popularity': 51},
#     {'id': 378424,
#      'name': 'Greatest Hits',
#      'upc': '886445003642',
#      'release_date': '2015-01-09T00:00:00.000Z',
#      'label': 'Arista/Legacy',
#      'image_url': 'https://i.scdn.co/image/48b059677e61f802b5515f99d2aee6a960b6d31a',
#      'popularity': 28},
#     {'id': 398002,
#      'name': 'Back In The Day ... Hip Hop Classics',
#      'upc': '886443040434',
#      'release_date': '2011-07-01T00:00:00.000Z',
#      'label': 'Sony Music UK',
#      'image_url': 'https://i.scdn.co/image/c18776686336e2ebfa80dd813b1419e9455fb222',
#      'popularity': 36},
#     {'id': 401884,
#      'name': 'Hip Hop 100 Hits - Urban rap & R n B anthems inc. Jay Z, A$ap Rocky, Wu-Tang Clan & Nas',
#      'upc': '886444019668',
#      'release_date': '2013-06-21T00:00:00.000Z',
#      'label': 'Sony Music Entertainment',
#      'image_url': 'https://i.scdn.co/image/30a6429aebac3db15fc0b561572347a3b4a739f5',
#      'popularity': 57},
#     {'id': 406156,
#      'name': 'Walk This Way - The Best Of',
#      'upc': '884977778687',
#      'release_date': '2010-10-22T00:00:00.000Z',
#      'label': 'Sony Music Entertainment',
#      'image_url': 'https://i.scdn.co/image/796f526fbb87bef8d3067ed918c6e9b33026c5c7',
#      'popularity': 24},
#     {'id': 640618,
#      'name': 'Ultimate Run Dmc',
#      'upc': '884977129823',
#      'release_date': '2003-10-28T00:00:00.000Z',
#      'label': 'Arista',
#      'image_url': 'https://i.scdn.co/image/0216ad5723dc1b82a0d0925a5787a3eea3eb9bda',
#      'popularity': 30},
#     {'id': 684104,
#      'name': "Pure... 80's Dance Party",
#      'upc': '886443002005',
#      'release_date': '2011-06-03T00:00:00.000Z',
#      'label': 'Sony Music Entertainment',
#      'image_url': 'https://i.scdn.co/image/b23ea6eb2f892fc9f40a93cd3879241be6982e68',
#      'popularity': 51},
#     {'id': 746593,
#      'name': 'Best Of',
#      'upc': '886970929523',
#      'release_date': '2007-05-05T00:00:00.000Z',
#      'label': 'SONY BMG Catalog',
#      'image_url': 'https://i.scdn.co/image/7ff97518e2d15447353453af7154761d0e159cd2',
#      'popularity': 33},
#     {'id': 755815,
#      'name': 'Turbo',
#      'upc': '886444001724',
#      'release_date': '2013-07-12T00:00:00.000Z',
#      'label': 'Sony Classical',
#      'image_url': 'https://i.scdn.co/image/1c743ac4b64a502fae0f7e6ab269b29e6b1561ab',
#      'popularity': 21},
#     {'id': 903672,
#      'name': 'The Essential Run-DMC',
#      'upc': '886444154840',
#      'release_date': '2012-10-30T00:00:00.000Z',
#      'label': 'Arista/Legacy',
#      'image_url': 'https://i.scdn.co/image/f7894d2516682e3de6f29ae1b1efff868cc2f2d1',
#      'popularity': 33},
#     {'id': 948539,
#      'name': 'Discover Run DMC',
#      'upc': '886971309126',
#      'release_date': '1984-01-01T00:00:00.000Z',
#      'label': 'Arista/Legacy',
#      'image_url': 'https://i.scdn.co/image/d5998e9bbcf077b44212bae26006b7d87647264a',
#      'popularity': 6},
#     {'id': 954816,
#      'name': 'Playlist: The Very Best Of RUN-DMC',
#      'upc': '888880816344',
#      'release_date': '1984-01-01T00:00:00.000Z',
#      'label': 'Arista',
#      'image_url': 'https://i.scdn.co/image/1154c1246c5d44021bacaf26d96ad289e2eb06d7',
#      'popularity': 1},
#     {'id': 1011784,
#      'name': 'Original Album Classics',
#      'upc': '888880734433',
#      'release_date': '1990-01-01T00:00:00.000Z',
#      'label': 'Arista/Legacy',
#      'image_url': 'https://i.scdn.co/image/4db4692865c361f76cb4f53804e0adbd23babb88',
#      'popularity': 0},
#     {'id': 1305073,
#      'name': 'Clubland Jump Around - The Ultimate Hip Hop Anthems',
#      'upc': '600753466728',
#      'release_date': '2013-01-01T00:00:00.000Z',
#      'label': 'UMOD (Universal Music On Demand)',
#      'image_url': 'https://i.scdn.co/image/ca1129e3107e60a1ee9afc705d67254dd242f27d',
#      'popularity': 0},
#     {'id': 1377853,
#      'name': 'Pure... Hip Hop',
#      'upc': '884977667516',
#      'release_date': '2010-01-01T00:00:00.000Z',
#      'label': 'Sony Music Entertainment',
#      'image_url': 'https://i.scdn.co/image/94190b460cfcca8409f5607c8227cfac43295d56',
#      'popularity': 35},
#     {'id': 1381285,
#      'name': 'Raising Hell',
#      'upc': '828766956122',
#      'release_date': '1986-05-15T00:00:00.000Z',
#      'label': 'Arista/Legacy',
#      'image_url': 'https://i.scdn.co/image/3860da3d814a28c84cca53c837ee1730881ed8b2',
#      'popularity': 30},
#     {'id': 1499835,
#      'name': 'RUN DMC "High Profile: The Original Rhymes"',
#      'upc': '743219478122',
#      'release_date': '2002-08-19T00:00:00.000Z',
#      'label': 'Arista',
#      'image_url': 'https://i.scdn.co/image/9cff1e58f29b773a804a535b106d217978a45129',
#      'popularity': 21},
#     {'id': 1527930,
#      'name': 'Raising Hell',
#      'upc': '828765541428',
#      'release_date': '1986-05-15T00:00:00.000Z',
#      'label': 'Arista',
#      'image_url': 'https://i.scdn.co/image/3860da3d814a28c84cca53c837ee1730881ed8b2',
#      'popularity': 15},
#     {'id': 1724503,
#      'name': 'Back & Forth',
#      'upc': '886445271249',
#      'release_date': '2015-07-10T00:00:00.000Z',
#      'label': 'Sony Music CG',
#      'image_url': 'https://i.scdn.co/image/283b79e5fb9ac78be86e3d167226ec6c374dc397',
#      'popularity': 28},
#     {'id': 1905320,
#      'name': 'Raising Hell',
#      'upc': '888880782557',
#      'release_date': '1986-05-15T00:00:00.000Z',
#      'label': 'Arista',
#      'image_url': 'https://i.scdn.co/image/3860da3d814a28c84cca53c837ee1730881ed8b2',
#      'popularity': 0},
#     {'id': 3176690,
#      'name': 'Hip To The Hop: 30th Anniversary Of Hip Hop Hip To Da Hop (International Version)',
#      'upc': '600753241394',
#      'release_date': '2009-12-25T00:00:00.000Z',
#      'label': 'Universal Music',
#      'image_url': 'https://api.deezer.com/album/467357/image',
#      'popularity': 34},
#     {'id': 3256699,
#      'name': 'Hip Hop - The Classics CD',
#      'upc': '600753031605',
#      'release_date': '2008-08-04T00:00:00.000Z',
#      'label': 'OOO Universal Music',
#      'image_url': 'https://api.deezer.com/album/102423/image',
#      'popularity': 4},
#     {'id': 3264675,
#      'name': 'Hip To The Hop: 30th Anniversary Of Hip Hop Hip To Da Hop (Single Disc Version)',
#      'upc': '600753241424',
#      'release_date': '2009-12-28T00:00:00.000Z',
#      'label': 'Universal Music',
#      'image_url': 'https://api.deezer.com/album/467358/image',
#      'popularity': 33},
#     {'id': 3280851,
#      'name': 'Turbo (Music From The Motion Picture)',
#      'upc': '810290020127',
#      'release_date': '2013-07-23T00:00:00.000Z',
#      'label': 'RELATIVITY MUSIC 2 (RM2)',
#      'image_url': 'https://api.deezer.com/album/6784536/image',
#      'popularity': 26},
#     {'id': 3970175,
#      'name': 'Greatest Hits',
#      'upc': '078221060721',
#      'release_date': '2002-09-10T00:00:00.000Z',
#      'label': 'Arista/BMG Heritage',
#      'image_url': 'https://i.scdn.co/image/b0a80863a41f96640a6ead9e112900a63fb7731e',
#      'popularity': 51},
#     {'id': 3970251,
#      'name': 'Raising Hell',
#      'upc': '078221640824',
#      'release_date': '1986-05-15T00:00:00.000Z',
#      'label': 'Arista',
#      'image_url': 'https://i.scdn.co/image/c86eba53f995224caead6f565e65b10ee5ed27d6',
#      'popularity': 65},
#     {'id': 4155586,
#      'name': 'Hip Hop 100 Hits - Urban rap & R n B anthems inc. Jay Z, A$ap Rocky, Wu-Tang Clan & Nas',
#      'upc': '886447689998',
#      'release_date': '2019-04-19T00:00:00.000Z',
#      'label': 'Sony Music Entertainment',
#      'image_url': 'https://i.scdn.co/image/30a6429aebac3db15fc0b561572347a3b4a739f5',
#      'popularity': 0}],
#    'tags': 'Hip-Hop/Rap,Music,Rock,Hardcore Rap,East Coast Rap,Hard Rock,Hip-Hop',
#    'cm_audio_features': {'key': 11,
#     'mode': 0,
#     'danceability': 0.966,
#     'energy': 0.954,
#     'speechiness': 0.229,
#     'acousticness': 0.00685,
#     'instrumentalness': 0,
#     'liveness': 0.0869,
#     'valence': 0.962,
#     'tempo': 128.126,
#     'loudness': -9.226},
#    'release_date': '2010-04-30T00:00:00.000Z',
#    'lastfm': {'name': "It's Tricky",
#     'url': 'https://www.last.fm/music/Run%E2%80%93D.M.C./_/It%27s+Tricky',
#     'duration': '183000',
#     'streamable': {'#text': '0', 'fulltrack': '0'},
#     'listeners': '65853',
#     'playcount': '214656',
#     'artist': {'name': 'Run–D.M.C.',
#      'url': 'https://www.last.fm/music/Run%E2%80%93D.M.C.'},
#     'album': {'artist': 'Various Artists',
#      'title': "100 Hits of the 80's - Volume 2",
#      'url': 'https://www.last.fm/music/Various+Artists/100+Hits+of+the+80%27s+-+Volume+2',
#      'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/be23ce0466d92244cfb8ab66cfdaa0a0.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/be23ce0466d92244cfb8ab66cfdaa0a0.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/be23ce0466d92244cfb8ab66cfdaa0a0.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/be23ce0466d92244cfb8ab66cfdaa0a0.png',
#        'size': 'extralarge'}]},
#     'toptags': {'tag': []}},
#    'cm_statistics': {'num_sp_playlists': 2958,
#     'num_sp_editorial_playlists': 12,
#     'num_am_playlists': 33,
#     'num_am_editorial_playlists': 5,
#     'num_de_playlists': 13,
#     'num_de_editorial_playlists': 5,
#     'num_az_playlists': 0,
#     'num_az_editorial_playlists': 0,
#     'num_yt_playlists': 0,
#     'num_yt_editorial_playlists': 0,
#     'yt_playlist_total_reach': None,
#     'sp_popularity': 67,
#     'sp_playlist_total_reach': '5943875',
#     'de_playlist_total_reach': '54942'}}},
#  'Classic (feat. POWERS) - RAC Remix': {'obj': {'id': 15089187,
#    'name': 'Classic (feat. POWERS) - RAC Remix',
#    'isrc': 'USAT21404380',
#    'image_url': 'https://i.scdn.co/image/0dbe8074aebb09955803cd027bd9a3d35cfca954',
#    'duration_ms': 262216,
#    'composer_name': 'Benjamin Ruttner, Crista Ru (Crista Russo), James Patterson & Mike Del Rio',
#    'artists': [{'id': 2189,
#      'name': 'The Knocks',
#      'mbid': '9157ad72-3893-47da-986a-0aa7313f7429',
#      'image_url': None,
#      'cover_url': None,
#      'code2': 'US',
#      'gender': 1,
#      'isni': None,
#      'description': None,
#      'created_at': '2016-11-26',
#      'hometown_city': None,
#      'current_city': None,
#      'date_of_birth': '2007-01-01',
#      'date_of_death': None},
#     {'id': 31595,
#      'name': 'POWERS',
#      'mbid': '03ba480f-7c17-4585-b357-3f413247baa8',
#      'image_url': None,
#      'cover_url': None,
#      'code2': 'CA',
#      'gender': 1,
#      'isni': None,
#      'description': None,
#      'created_at': '2016-11-26',
#      'hometown_city': None,
#      'current_city': None,
#      'date_of_birth': None,
#      'date_of_death': None},
#     {'id': 207310,
#      'name': 'RAC',
#      'mbid': None,
#      'image_url': None,
#      'cover_url': None,
#      'code2': 'US',
#      'gender': 1,
#      'isni': None,
#      'description': None,
#      'created_at': '2016-11-25',
#      'hometown_city': 7011,
#      'current_city': None,
#      'date_of_birth': None,
#      'date_of_death': None}],
#    'albums': [{'id': 3963138,
#      'name': 'Classic (feat. POWERS) [Remixes]',
#      'upc': '075679909954',
#      'release_date': '2016-04-28T00:00:00.000Z',
#      'label': 'Big Beat/Neon Gold',
#      'image_url': 'https://i.scdn.co/image/0dbe8074aebb09955803cd027bd9a3d35cfca954',
#      'popularity': 28},
#     {'id': 3964255,
#      'name': 'Classic (feat. POWERS) [Remixes]',
#      'upc': '075679933133',
#      'release_date': '2014-10-21T00:00:00.000Z',
#      'label': 'Big Beat/Neon Gold',
#      'image_url': 'https://i.scdn.co/image/8ebd907519369a19e6f295c23c2741f69463e10c',
#      'popularity': 20}],
#    'tags': 'Dance,Music',
#    'cm_audio_features': {'key': 2,
#     'mode': 1,
#     'danceability': 0.647,
#     'energy': 0.776,
#     'speechiness': 0.0466,
#     'acousticness': 0.00456,
#     'instrumentalness': 0.0261,
#     'liveness': 0.0535,
#     'valence': 0.555,
#     'tempo': 101.991,
#     'loudness': -5.801},
#    'release_date': '2016-04-28T00:00:00.000Z',
#    'lastfm': {'name': 'Classic (feat. Powers) - RAC Remix',
#     'url': 'https://www.last.fm/music/The+Knocks/_/Classic+(feat.+Powers)+-+RAC+Remix',
#     'duration': '0',
#     'streamable': {'#text': '0', 'fulltrack': '0'},
#     'listeners': '4383',
#     'playcount': '12043',
#     'artist': {'name': 'The Knocks',
#      'mbid': '9157ad72-3893-47da-986a-0aa7313f7429',
#      'url': 'https://www.last.fm/music/The+Knocks'},
#     'toptags': {'tag': []}},
#    'cm_statistics': {'num_sp_playlists': 104,
#     'num_sp_editorial_playlists': 0,
#     'num_am_playlists': 0,
#     'num_am_editorial_playlists': 0,
#     'num_de_playlists': 0,
#     'num_de_editorial_playlists': 0,
#     'num_az_playlists': 0,
#     'num_az_editorial_playlists': 0,
#     'num_yt_playlists': 0,
#     'num_yt_editorial_playlists': 0,
#     'yt_playlist_total_reach': None,
#     'sp_popularity': 25,
#     'sp_playlist_total_reach': '103631',
#     'de_playlist_total_reach': None}}},
#  'Did You Wrong (feat. MAX)': {'obj': {'id': 15092020,
#    'name': 'Did You Wrong (feat. MAX)',
#    'isrc': 'USAT21602118',
#    'image_url': 'https://i.scdn.co/image/2b8af91848141236b0b2f22bcd2d4a447504adaa',
#    'duration_ms': 221205,
#    'composer_name': None,
#    'artists': [{'id': 208481,
#      'name': 'Sweater Beats',
#      'mbid': '91f5de33-2dd1-49cf-ad92-3b794ccc14a7',
#      'image_url': None,
#      'cover_url': None,
#      'code2': 'US',
#      'gender': 1,
#      'isni': None,
#      'description': None,
#      'created_at': '2016-11-26',
#      'hometown_city': None,
#      'current_city': None,
#      'date_of_birth': None,
#      'date_of_death': None},
#     {'id': 5614,
#      'name': 'MAX',
#      'mbid': '2281c623-f9fe-4df4-b549-5cc8c39654fc',
#      'image_url': 'https://i.scdn.co/image/7be5ff4179351749766dd88dad735a8b3562f46b',
#      'cover_url': 'https://i.scdn.co/image/3019302b174394ade81222c2ae6ac0690473a76c',
#      'code2': 'US',
#      'gender': 1,
#      'isni': None,
#      'description': 'A New York City-born, Woodstock-raised pop/soul singer, actor, and dancer in the vein of artists like Bruno Mars, Cody Simpson, and One Direction, Maxwell George "MAX" Schneider began honing his chops at the age of three. ',
#      'created_at': '2016-11-26',
#      'hometown_city': 6345,
#      'current_city': None,
#      'date_of_birth': '1995-01-01',
#      'date_of_death': None}],
#    'albums': [{'id': 3962963,
#      'name': 'Did You Wrong (feat. MAX)',
#      'upc': '075679906915',
#      'release_date': '2016-10-21T00:00:00.000Z',
#      'label': 'Big Beat Records',
#      'image_url': 'https://i.scdn.co/image/6692b8cb1025cb77b2e9a4da713a3e3ec99f592f',
#      'popularity': 22},
#     {'id': 3962967,
#      'name': 'For The Cold EP',
#      'upc': '075679906960',
#      'release_date': '2017-07-07T00:00:00.000Z',
#      'label': 'Big Beat Records',
#      'image_url': 'https://i.scdn.co/image/2b8af91848141236b0b2f22bcd2d4a447504adaa',
#      'popularity': 35}],
#    'tags': 'Electronic',
#    'cm_audio_features': {'key': 10,
#     'mode': 0,
#     'danceability': 0.596,
#     'energy': 0.746,
#     'speechiness': 0.076,
#     'acousticness': 0.134,
#     'instrumentalness': 1.01e-06,
#     'liveness': 0.299,
#     'valence': 0.473,
#     'tempo': 99.03,
#     'loudness': -4.411},
#    'release_date': '2016-10-21T00:00:00.000Z',
#    'lastfm': {'name': 'Did You Wrong (feat. MAX)',
#     'url': 'https://www.last.fm/music/Sweater+Beats/_/Did+You+Wrong+(feat.+MAX)',
#     'duration': '221000',
#     'streamable': {'#text': '0', 'fulltrack': '0'},
#     'listeners': '6048',
#     'playcount': '19808',
#     'artist': {'name': 'Sweater Beats',
#      'mbid': '91f5de33-2dd1-49cf-ad92-3b794ccc14a7',
#      'url': 'https://www.last.fm/music/Sweater+Beats'},
#     'album': {'artist': 'Sweater Beats',
#      'title': 'Did You Wrong (feat. MAX)',
#      'url': 'https://www.last.fm/music/Sweater+Beats/Did+You+Wrong+(feat.+MAX)',
#      'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/8fda6fdcf670af82598cc339a410b5b0.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/8fda6fdcf670af82598cc339a410b5b0.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/8fda6fdcf670af82598cc339a410b5b0.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/8fda6fdcf670af82598cc339a410b5b0.png',
#        'size': 'extralarge'}]},
#     'toptags': {'tag': [{'name': 'nu-disco',
#        'url': 'https://www.last.fm/tag/nu-disco'},
#       {'name': 'future bass', 'url': 'https://www.last.fm/tag/future+bass'}]}},
#    'cm_statistics': {'num_sp_playlists': 102,
#     'num_sp_editorial_playlists': 0,
#     'num_am_playlists': 0,
#     'num_am_editorial_playlists': 0,
#     'num_de_playlists': 0,
#     'num_de_editorial_playlists': 0,
#     'num_az_playlists': 0,
#     'num_az_editorial_playlists': 0,
#     'num_yt_playlists': 0,
#     'num_yt_editorial_playlists': 0,
#     'yt_playlist_total_reach': None,
#     'sp_popularity': 31,
#     'sp_playlist_total_reach': '208533',
#     'de_playlist_total_reach': None}}},
#  'Taped Up Heart (feat. Clara Mae)': {'obj': {'id': 15092425,
#    'name': 'Taped Up Heart (feat. Clara Mae)',
#    'isrc': 'USAT21602970',
#    'image_url': 'https://i.scdn.co/image/88ddd2608786ea13247ea4d46ec1e053c3cad8dd',
#    'duration_ms': 218506,
#    'composer_name': None,
#    'artists': [{'id': 19723,
#      'name': 'KREAM',
#      'mbid': '60a7048e-42fd-450b-b820-6f386c454360',
#      'image_url': 'https://i.scdn.co/image/1eef03e6bd6ab5358223beaef37f32f15fb92590',
#      'cover_url': 'https://i.scdn.co/image/afafff0dfee7ae4f8dee7babf177cad926490c28',
#      'code2': 'NO',
#      'gender': 1,
#      'isni': None,
#      'description': 'Norwegian duo KREAM are known for high-energy electronic pop music, often contrasted with moody undertones. Hailing from Bergen, Norway, KREAM features the talents of brothers Daniel and Markus Slettebakken. Initially discovered on SoundCloud through their remixes, the duo chose to partner with Big Beat/Atlantic Records. Soon after they delivered hit single &quot;Taped Up Heart,&quot; featuring Swedish vocalist Clara Mae. The song peaked at #21 on Billboard&#39;s Dance/Electronic chart and has racked up 100+ Million streams.\n\nRecent releases include “Enough,” a collab with Cazztek and Shoffy, “Decisions” featuring Maia Wright and “Deep End” feat. JHart whose Eden Prince Remix spent weeks in the top spot of Spotify’s Mint playlist. KREAM continues to produce official remixes for major artists such as Dua Lipa, Anne Marie, Tove Lo, Bazzi, Zara Larsson, Kyle &amp; Kehlani and Jess Glynne.\n\nThe beginning of 2019 saw KREAM embark on their first US tour with Lost Kings before heading to Europe with Matoma. Off the stage, the pair has been productive in the studio and will soon be releasing music to show it!\n',
#      'created_at': '2016-11-26',
#      'hometown_city': 4457,
#      'current_city': None,
#      'date_of_birth': None,
#      'date_of_death': None}],
#    'albums': [{'id': 3962772,
#      'name': 'Taped Up Heart (feat. Clara Mae)',
#      'upc': '075679903570',
#      'release_date': '2016-10-14T00:00:00.000Z',
#      'label': 'Big Beat Records',
#      'image_url': 'https://i.scdn.co/image/88ddd2608786ea13247ea4d46ec1e053c3cad8dd',
#      'popularity': 49}],
#    'tags': 'Dance,Music',
#    'cm_audio_features': {'key': 0,
#     'mode': 0,
#     'danceability': 0.675,
#     'energy': 0.937,
#     'speechiness': 0.0509,
#     'acousticness': 0.152,
#     'instrumentalness': 0,
#     'liveness': 0.154,
#     'valence': 0.57,
#     'tempo': 103.961,
#     'loudness': -3.525},
#    'release_date': '2016-10-14T00:00:00.000Z',
#    'lastfm': {'name': 'Taped Up Heart (feat. Clara Mae)',
#     'url': 'https://www.last.fm/music/Kream/_/Taped+Up+Heart+(feat.+Clara+Mae)',
#     'duration': '218000',
#     'streamable': {'#text': '0', 'fulltrack': '0'},
#     'listeners': '45435',
#     'playcount': '164547',
#     'artist': {'name': 'Kream', 'url': 'https://www.last.fm/music/Kream'},
#     'album': {'artist': 'Kream',
#      'title': 'Taped Up Heart (feat. Clara Mae)',
#      'url': 'https://www.last.fm/music/Kream/Taped+Up+Heart+(feat.+Clara+Mae)',
#      'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/ae6cdf45bcf0da06a97b488b0392ce02.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/ae6cdf45bcf0da06a97b488b0392ce02.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/ae6cdf45bcf0da06a97b488b0392ce02.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/ae6cdf45bcf0da06a97b488b0392ce02.png',
#        'size': 'extralarge'}]},
#     'toptags': {'tag': [{'name': 'pop', 'url': 'https://www.last.fm/tag/pop'},
#       {'name': 'dance', 'url': 'https://www.last.fm/tag/dance'},
#       {'name': 'House', 'url': 'https://www.last.fm/tag/House'},
#       {'name': 'EDM', 'url': 'https://www.last.fm/tag/EDM'}]}},
#    'cm_statistics': {'num_sp_playlists': 1083,
#     'num_sp_editorial_playlists': 20,
#     'num_am_playlists': 11,
#     'num_am_editorial_playlists': 0,
#     'num_de_playlists': 1,
#     'num_de_editorial_playlists': 0,
#     'num_az_playlists': 0,
#     'num_az_editorial_playlists': 0,
#     'num_yt_playlists': 0,
#     'num_yt_editorial_playlists': 0,
#     'yt_playlist_total_reach': None,
#     'sp_popularity': 53,
#     'sp_playlist_total_reach': '785191',
#     'de_playlist_total_reach': '6'}}},
#  'Aftershock (feat. Jacquie Lee)': {'obj': {'id': 15091180,
#    'name': 'Aftershock (feat. Jacquie Lee)',
#    'isrc': 'USAT21600001',
#    'image_url': 'https://i.scdn.co/image/0504e69e54511caea80d4f9be10f5ff1e588d569',
#    'duration_ms': 206320,
#    'composer_name': None,
#    'artists': [{'id': 3403,
#      'name': 'Cash Cash',
#      'mbid': 'dda162b4-f871-4e89-b081-b7b3470782f0',
#      'image_url': None,
#      'cover_url': None,
#      'code2': 'US',
#      'gender': 1,
#      'isni': None,
#      'description': None,
#      'created_at': '2016-11-26',
#      'hometown_city': 7060,
#      'current_city': None,
#      'date_of_birth': '2006-01-01',
#      'date_of_death': None},
#     {'id': 206951,
#      'name': 'Jacquie Lee',
#      'mbid': 'f5cb2b4f-bfba-4bfc-9d70-82d138829717',
#      'image_url': None,
#      'cover_url': None,
#      'code2': 'US',
#      'gender': 0,
#      'isni': None,
#      'description': None,
#      'created_at': '2016-11-26',
#      'hometown_city': None,
#      'current_city': None,
#      'date_of_birth': '1997-06-25',
#      'date_of_death': None}],
#    'albums': [{'id': 3963129,
#      'name': 'Blood, Sweat & 3 Years',
#      'upc': '075679909848',
#      'release_date': '2016-06-24T00:00:00.000Z',
#      'label': 'Big Beat Records',
#      'image_url': 'https://i.scdn.co/image/0504e69e54511caea80d4f9be10f5ff1e588d569',
#      'popularity': 54},
#     {'id': 3963213,
#      'name': 'Blood, Sweat & 3 Years',
#      'upc': '075679911452',
#      'release_date': '2016-06-24T00:00:00.000Z',
#      'label': 'Big Beat Records',
#      'image_url': 'https://i.scdn.co/image/0504e69e54511caea80d4f9be10f5ff1e588d569',
#      'popularity': 57},
#     {'id': 3963370,
#      'name': 'Aftershock (feat. Jacquie Lee)',
#      'upc': '075679914354',
#      'release_date': '2016-01-29T00:00:00.000Z',
#      'label': 'Big Beat Records',
#      'image_url': 'https://i.scdn.co/image/a538ddccb3f3f63abf1290c25efb559105409928',
#      'popularity': 27}],
#    'tags': 'Dance',
#    'cm_audio_features': {'key': 8,
#     'mode': 1,
#     'danceability': 0.549,
#     'energy': 0.834,
#     'speechiness': 0.0515,
#     'acousticness': 0.052,
#     'instrumentalness': 0,
#     'liveness': 0.121,
#     'valence': 0.193,
#     'tempo': 129.011,
#     'loudness': -2.75},
#    'release_date': '2016-06-24T00:00:00.000Z',
#    'lastfm': {'name': 'Aftershock (feat. Jacquie Lee)',
#     'url': 'https://www.last.fm/music/Cash+Cash/_/Aftershock+(feat.+Jacquie+Lee)',
#     'duration': '206000',
#     'streamable': {'#text': '0', 'fulltrack': '0'},
#     'listeners': '14182',
#     'playcount': '59717',
#     'artist': {'name': 'Cash Cash',
#      'mbid': 'dda162b4-f871-4e89-b081-b7b3470782f0',
#      'url': 'https://www.last.fm/music/Cash+Cash'},
#     'album': {'artist': 'Cash Cash',
#      'title': 'Aftershock (feat. Jacquie Lee)',
#      'url': 'https://www.last.fm/music/Cash+Cash/Aftershock+(feat.+Jacquie+Lee)',
#      'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/c585f0f33219372b52bc3191e10fd884.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/c585f0f33219372b52bc3191e10fd884.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/c585f0f33219372b52bc3191e10fd884.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/c585f0f33219372b52bc3191e10fd884.png',
#        'size': 'extralarge'}]},
#     'toptags': {'tag': [{'name': 'dance',
#        'url': 'https://www.last.fm/tag/dance'},
#       {'name': 'sevadus', 'url': 'https://www.last.fm/tag/sevadus'}]}},
#    'cm_statistics': {'num_sp_playlists': 502,
#     'num_sp_editorial_playlists': 2,
#     'num_am_playlists': 11,
#     'num_am_editorial_playlists': 2,
#     'num_de_playlists': 0,
#     'num_de_editorial_playlists': 0,
#     'num_az_playlists': 0,
#     'num_az_editorial_playlists': 0,
#     'num_yt_playlists': 0,
#     'num_yt_editorial_playlists': 0,
#     'yt_playlist_total_reach': None,
#     'sp_popularity': 45,
#     'sp_playlist_total_reach': '687417',
#     'de_playlist_total_reach': None}}}}

# %%
song_features_dict = {} 
for k, v in song_data_dict.items():
    song_features_dict[k] = v['obj']['cm_audio_features']
feature_df = pd.DataFrame.from_dict(song_features_dict).T
feature_df.drop(columns=["key", "loudness", "mode", "tempo"], inplace=True)

# %%
def sim_function(x, y):
    return 1. / (1. + np.linalg.norm(x - y, 2))

# %%
n = len(feature_df)
sim_song = {}
X = np.zeros((n, 7))

for i in range(n):
    X[i] = feature_df.iloc[i]
    
for i in range(n):
    x = feature_df.iloc[i]
    sim_song[x.name] = 0
    buffer = 0
    for j in range(n):
        if i == j:
            continue
            
        y = feature_df.iloc[j]
        
        sim = sim_function(x, y)
        if sim > buffer:
            sim_song[x.name] = y.name
            buffer = sim

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca.fit(X)

z = pca.transform(X)
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(7 * 1.6, 7))
for i, vec in enumerate(z):
    ax.scatter(vec[0], vec[1], label=feature_df.iloc[i].name)
plt.legend(loc="best", ncol=5, bbox_to_anchor=(0, 1.02, 1, 0.102),
          frameon=False, borderpad=2)
plt.show()

# %%
# System modules
from queue import Queue
from threading import Thread
import time

# Local modules
import feedparser

# Set up some global variables
num_fetch_threads = 2
enclosure_queue = Queue()

# A real app wouldn't use hard-coded data...
feed_urls = [ 'http://www.castsampler.com/cast/feed/rss/guest',
             ]


def downloadEnclosures(i, q):
    """This is the worker thread function.
    It processes items in the queue one after
    another.  These daemon threads go into an
    infinite loop, and only exit when
    the main thread ends.
    """
    while True:
        print('%s: Looking for the next enclosure' % i)
        url = q.get()
        print('%s: Downloading:' % i, url)
        # instead of really downloading the URL,
        # we just pretend and sleep
        time.sleep(i + 2)
        q.task_done()


# Set up some threads to fetch the enclosures
for i in range(num_fetch_threads):
    worker = Thread(target=downloadEnclosures, args=(i, enclosure_queue,))
    worker.setDaemon(True)
    worker.start()

# Download the feed(s) and put the enclosure URLs into
# the queue.
for url in feed_urls:
    response = feedparser.parse(url, agent='fetch_podcasts.py')
    for entry in response['entries']:
        for enclosure in entry.get('enclosures', []):
            print('Queuing:', enclosure['url'])
            enclosure_queue.put(enclosure['url'])
        
# Now wait for the queue to be empty, indicating that we have
# processed all of the downloads.
print('*** Main thread waiting')
enclosure_queue.join()
print('*** Done')
# Out:
# 0: Looking for the next enclosure
# 1: Looking for the next enclosure
# *** Main thread waiting
# *** Done
